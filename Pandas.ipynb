# %% [markdown]
# <a href="https://colab.research.google.com/github/arturo-romer/Tarea-1/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

s = pd.Series([10, 20, 30, 40, 50])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
df = pd.DataFrame([
   [10, "ten", True],
   [20, "twenty", False],
   [30, "thirty", True]
])
print(df)
print(df.shape)
# Out:
#     0       1      2
# 0  10     ten   True
# 1  20  twenty  False
# 2  30  thirty   True
# (3, 3)

# %%
import numpy as np
df1 = pd.DataFrame(np.arange(100).reshape((20,5)))
df1
# Out:
#      0   1   2   3   4
# 0    0   1   2   3   4
# 1    5   6   7   8   9
# 2   10  11  12  13  14
# 3   15  16  17  18  19
# 4   20  21  22  23  24
# 5   25  26  27  28  29
# 6   30  31  32  33  34
# 7   35  36  37  38  39
# 8   40  41  42  43  44
# 9   45  46  47  48  49
# 10  50  51  52  53  54
# 11  55  56  57  58  59
# 12  60  61  62  63  64
# 13  65  66  67  68  69
# 14  70  71  72  73  74
# 15  75  76  77  78  79
# 16  80  81  82  83  84
# 17  85  86  87  88  89
# 18  90  91  92  93  94
# 19  95  96  97  98  99

# %%
df1.head()
df1.head(10)
# Out:
#     0   1   2   3   4
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19
# 4  20  21  22  23  24
# 5  25  26  27  28  29
# 6  30  31  32  33  34
# 7  35  36  37  38  39
# 8  40  41  42  43  44
# 9  45  46  47  48  49

# %%
df1.info()
df1.size
df1.shape
df1.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       20 non-null     int64
#  1   1       20 non-null     int64
#  2   2       20 non-null     int64
#  3   3       20 non-null     int64
#  4   4       20 non-null     int64
# dtypes: int64(5)
# memory usage: 932.0 bytes
#                0          1          2          3          4
# count  20.000000  20.000000  20.000000  20.000000  20.000000
# mean   47.500000  48.500000  49.500000  50.500000  51.500000
# std    29.580399  29.580399  29.580399  29.580399  29.580399
# min     0.000000   1.000000   2.000000   3.000000   4.000000
# 25%    23.750000  24.750000  25.750000  26.750000  27.750000
# 50%    47.500000  48.500000  49.500000  50.500000  51.500000
# 75%    71.250000  72.250000  73.250000  74.250000  75.250000
# max    95.000000  96.000000  97.000000  98.000000  99.000000

# %%
df2 = pd.DataFrame(np.arange(9).reshape((3,3)))
df2
# Out:
#    0  1  2
# 0  0  1  2
# 1  3  4  5
# 2  6  7  8

# %%
df2.index = ["x","y","z"]
df2.columns = ["a", "b", "c"]
df2

#or

df3 = pd.DataFrame(np.arange(9).reshape((3,3)), index=["row1","row2", "row3"], columns=["col1", "col2","col3"])
df3
# Out:
#       col1  col2  col3
# row1     0     1     2
# row2     3     4     5
# row3     6     7     8

# %%
df4 = pd.DataFrame({"columns A":[1, 2, 3], "column B": [4, 5, 6], "column C": [7, 8, 9]})
df4
# Out:
#    columns A  column B  column C
# 0          1         4         7
# 1          2         5         8
# 2          3         6         9

# %%
df5 = pd.DataFrame(np.arange(20).reshape((5,4))), index = ["1st line", "2nd line", "3rd line"]
